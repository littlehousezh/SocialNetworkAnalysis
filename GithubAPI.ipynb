# %%
#This script read in a list of repos of interest (from the repo_file
#input), then for each repo,dump the json obj of it and get all its contributors and their info,
#finally output contirbutors' info into the output file.

# NOTE:
# https://api.github.com/repos/democracyworks/voting-method-works
# https://api.github.com/erpos/opendatateam/croquemort
#https://api.github.com/repos/Project-AsTeR/*
# no longer exists

import requests, json
import os
from pprint import pprint
import csv
import sys
import time
import pandas as pd


#read in the repo list
# repo_file = "./ovio-covid19-projects.csv"
# repo_file = "./ovio-all-projects-6.csv"
# outpath = "./ovio-covid19-contributors/"
# outpath = "./ovio-all-contributors/"
repo_file = sys.argv[1]
outpath = sys.argv[2]
#ID = sys.argv[3]
#PW = sys.argv[4]

# my_reader = csv.DictReader(open(repo_file))
repo=pd.read_csv('repo_file.csv')

repo_list = []
# for row in my_reader:
#     repo_name_with_owner = row["repo_name_with_owner"] # e.g., "reach4help/reach4help"
#     repo_list.append(repo_name_with_owner)
for row in range(len(repo['repo_name'])):
    repo_list.append(repo['repo_name'][row])
 
headers = {'User-Agent':'Mozilla/5.0',
    'Authorization':'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',
    'Content-Type':'application/json',
    'method':'GET',
    'Accept':'application/json'}
def main():
    with open("./repo_contributors_count.csv", 'w') as of:
        # get each repo api url

        for repo_name in repo_list:
            url = "https://api.github.com/repos/"+ repo_name
            repo_req = requests.get(url, headers) #auth = (ID, PW))
            repo = repo_req.json()
            with open('./repo-json/'+repo_name.replace('/','_')+'.json','w') as out:
                json.dump(repo,out)
                time.sleep(1)
            



            contributor_url = url+'/contributors'
            req = requests.get(contributor_url, headers) #auth = (ID, PW))
            time.sleep(1)

            contributors = req.json() # contributors is a list of json files, each elelment is a json object that represents a contributor
            num_contributors = len(contributors)
            of.write(repo_name+', '+ str(num_contributors)+"\n")

            
            outfile = outpath+repo_name.replace('/','_')+".csv"
            my_writer = csv.writer(open(outfile, 'w'))
            header_line = ['name', 'u_name', 'email', 'url', 'contributions', 'location', 'company', 'public_repos', 'followers', 'following', 'bio']
            my_writer.writerow(header_line)

            print("REPO:"+repo_name) 
            print("c-url:"+contributor_url) 
            #pprint(contributors)
            for c in contributors:
                #print(c)
                try:
                    c_uname = c["login"]
                    c_name, c_email = get_u_info(c)
                    c_num_contribution = c["contributions"]
                    c_uname = c["login"]
                    c_url = "https://api.github.com/users/"+c_uname
                    c_website_req = requests.get(c_url, headers) #auth = (ID, PW))
                    c_jobj = c_website_req.json()
                    c_company = c_jobj["company"]
                    c_location = c_jobj["location"]
                    c_bio = c_jobj["bio"]
                    c_num_pub_repos = c_jobj["public_repos"]
                    c_num_followers = c_jobj["followers"]
                    c_num_following = c_jobj["following"]

                    line = [c_name, c_uname, c_email, c_url, c_num_contribution, c_location, c_company, c_num_pub_repos, c_num_followers, c_num_following, c_bio]

                    my_writer.writerow(line)
                except TypeError:
                    continue


def get_u_info(c): # c is a contributor json obj
    c_uname = c["login"]
    event_url = "https://api.github.com/users/"+c_uname+'/events/public'
    event_req = requests.get(event_url, headers) #auth = (ID, PW))
    time.sleep(3)
    events = event_req.json()
    #pprint(events)
    email = ""
    name = ""
    #print("!!!!!!!UNAME:"+c_uname)
    for event in events:
        try:
            email = event['payload']['commits'][0]['author']['email'] 
            name = event['payload']['commits'][0]['author']['name'] 
            if email != '' and name != '':
                print(email)
                print(name)
                break
        except (KeyError, IndexError) as e:
            continue
    return [name, email]

if __name__ == '__main__':
    main()
# Out:
# REPO:rustdesk/rustdesk
# c-url:https://api.github.com/repos/rustdesk/rustdesk/contributors
# csf@breakbeat.cn
# csf
# 71636191+rustdesk@users.noreply.github.com
# RustDesk
# zhouhuab@163.com
# open-trade
# csf@breakbeat.cn
# csf
# shuanglongchen@yeah.net
# fufesou
# 16441688+chenbaiyu0414@users.noreply.github.com
# Baiyu Chen
# 73812536+upptime-bot@users.noreply.github.com
# Upptime Bot
# saverio.pub2@gmail.com
# Saverio Miroddi
# 71702982+varghesejose2020@users.noreply.github.com
# Varghese Jose
# 49699333+dependabot[bot]@users.noreply.github.com
# dependabot[bot]
# 90960002+cc-morning@users.noreply.github.com
# cc-morning
# 49699333+dependabot[bot]@users.noreply.github.com
# dependabot[bot]
# 20495460+ACMCMC@users.noreply.github.com
# Aldán Creo
# 63919734+ViktorOn@users.noreply.github.com
# Vik
# rizlas@users.noreply.github.com
# rizlas
# 92984096+MarcelKuesters@users.noreply.github.com
# Marcel Küsters
# kagbe.leviy@gmail.com
# Woozy Masta
# me@gteng.org
# gengteng
# pavel.borecki@gmail.com
# p-bo
# 3522081+planetzcitizen@users.noreply.github.com
# planetzcitizen
# 77976308+b1ue64@users.noreply.github.com
# b1ue64
# 71834579+josephjosedev@users.noreply.github.com
# Joseph Jose
# mateusauler@protonmail.com
# Mateus Auler
# rewrite0w0@gmail.com
# Oh TaeJun
# wrongthingtodo@gmail.com
# Radion Mynayev
# nelson22768384@gmail.com
# SiderealArt
# REPO:elastic/elasticsearch
# c-url:https://api.github.com/repos/elastic/elasticsearch/contributors
# REPO:photonstorm/phaser
# c-url:https://api.github.com/repos/photonstorm/phaser/contributors
# REPO:angular/angular
# c-url:https://api.github.com/repos/angular/angular/contributors
# REPO:ansh/bionic-reading
# c-url:https://api.github.com/repos/ansh/bionic-reading/contributors
# REPO:ethereum/go-ethereum
# c-url:https://api.github.com/repos/ethereum/go-ethereum/contributors
# REPO:alibaba/fastjson
# c-url:https://api.github.com/repos/alibaba/fastjson/contributors
# REPO:kubernetes/kubernetes
# c-url:https://api.github.com/repos/kubernetes/kubernetes/contributors
# REPO:prettier/prettier
# c-url:https://api.github.com/repos/prettier/prettier/contributors
# REPO:Geal/nom
# c-url:https://api.github.com/repos/Geal/nom/contributors
# REPO:facebook/react
# c-url:https://api.github.com/repos/facebook/react/contributors
# REPO:alphagov/whitehall
# c-url:https://api.github.com/repos/alphagov/whitehall/contributors
# REPO:nysenate/OpenLegislation
# c-url:https://api.github.com/repos/nysenate/OpenLegislation/contributors
# REPO:resource-watch/resource-watch
# c-url:https://api.github.com/repos/resource-watch/resource-watch/contributors
# REPO:CodeForAfrica/HealthTools.KE-theStarHealth
# c-url:https://api.github.com/repos/CodeForAfrica/HealthTools.KE-theStarHealth/contributors
# REPO:developmentseed/label-maker
# c-url:https://api.github.com/repos/developmentseed/label-maker/contributors
# REPO:publiclab/infragram
# c-url:https://api.github.com/repos/publiclab/infragram/contributors
# REPO:code4romania/seismic-risc
# c-url:https://api.github.com/repos/code4romania/seismic-risc/contributors
# REPO:OperationCode/front-end
# c-url:https://api.github.com/repos/OperationCode/front-end/contributors
# REPO:sugarlabs/musicblocks
# c-url:https://api.github.com/repos/sugarlabs/musicblocks/contributors
# REPO:moodle/moodle
# c-url:https://api.github.com/repos/moodle/moodle/contributors
# REPO:openfoodfacts/openfoodfacts-androidapp
# c-url:https://api.github.com/repos/openfoodfacts/openfoodfacts-androidapp/contributors
# REPO:tmrowco/electricitymap-contrib
# c-url:https://api.github.com/repos/tmrowco/electricitymap-contrib/contributors
# REPO:openmrs/openmrs-core
# c-url:https://api.github.com/repos/openmrs/openmrs-core/contributors
# REPO:nvaccess/nvda
# c-url:https://api.github.com/repos/nvaccess/nvda/contributors
# REPO:openMF/community-app
# c-url:https://api.github.com/repos/openMF/community-app/contributors
# REPO:DPGAlliance/publicgoods-api
# c-url:https://api.github.com/repos/DPGAlliance/publicgoods-api/contributors
# REPO:DPGAlliance/publicgoods-candidates
# c-url:https://api.github.com/repos/DPGAlliance/publicgoods-candidates/contributors
# REPO:DPGAlliance/DPG-Standard
# c-url:https://api.github.com/repos/DPGAlliance/DPG-Standard/contributors
# REPO:DPGAlliance/publicgoods-scripts
# c-url:https://api.github.com/repos/DPGAlliance/publicgoods-scripts/contributors
# REPO:DPGAlliance/publicgoods-validate
# c-url:https://api.github.com/repos/DPGAlliance/publicgoods-validate/contributors
# REPO:DPGAlliance/publicgoods-submission
# c-url:https://api.github.com/repos/DPGAlliance/publicgoods-submission/contributors
# REPO:DPGAlliance/publicgoods-form-opens-pr
# c-url:https://api.github.com/repos/DPGAlliance/publicgoods-form-opens-pr/contributors

# %%
repo_file1 = sys.argv[1]
outpath1 = sys.argv[2]
repo_file1
# Out:
# '-f'
